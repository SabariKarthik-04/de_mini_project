# %%
data = spark.read.table("`01_bronze`.raw.products")
display(data)

# %%
from pyspark.sql.functions import col, sum

null_counts = data.select([sum(col(c).isNull()).alias(c) for c in data.columns])
display(null_counts)
